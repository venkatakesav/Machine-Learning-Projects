# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
data = pd.read_csv('train_data.csv')
data = data.values

X = data[:, 0]
Y = data[:, 1]

X = np.array([np.array([ord(c) - ord('a') + 1 for c in s]) for s in X])
Y = np.array([np.array([ord(c) - ord('a') + 1 for c in s]) for s in Y])
Y = np.array([np.append([0], y) for y in Y])

# Load Test data
test_data = pd.read_csv('eval_data.csv')
test_data = test_data.values

X_test = test_data[:,0]
Y_test = test_data[:,1]

X_test = np.array([np.array([ord(c) - ord('a') + 1 for c in s]) for s in X_test])
Y_test = np.array([np.array([ord(c) - ord('a') + 1 for c in s]) for s in Y_test])
Y_test = np.array([np.append([0], y) for y in Y_test])

# convert to torch tensors
X = torch.tensor(X)
Y = torch.tensor(Y)
X_test = torch.tensor(X_test)
Y_test = torch.tensor(Y_test)

print(X.shape, Y.shape, X_test.shape, Y_test.shape)
# Out:
# torch.Size([7000, 8]) torch.Size([7000, 9]) torch.Size([2000, 8]) torch.Size([2000, 9])

# %%
# Positional Encoding
import math
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=7000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).view(-1,1)  
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)
        
    def forward(self, x: torch.tensor)->torch.tensor:
        return self.dropout(x + self.pe[:x.size(0), :])

# %%
# Transformer Model using nn.Transformer
class TransformerModel(nn.Module):
    def __init__(self, n_tokens, d_model, n_heads, n_encoder_layers, n_decoder_layers, dropout):
        super().__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model
        # layers
        self.embedding = nn.Embedding(n_tokens, d_model)
        self.pos_encoder = PositionalEncoding(d_model, dropout)
        self.transformer = nn.Transformer(d_model, n_heads, n_encoder_layers, n_decoder_layers, dropout=dropout, batch_first=True)
        self.decoder = nn.Linear(d_model, n_tokens)
        # apply softmax to output
        self.softmax = nn.LogSoftmax(dim=2)

    def forward(self, src, tgt):
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        tgt = self.embedding(tgt) * math.sqrt(self.d_model)
        tgt = self.pos_encoder(tgt)
        output = self.transformer(src, tgt)
        output = self.decoder(output)
        output = self.softmax(output)
        return output

    def predict(model,input_str):
        model.eval()
        output = ''
        input_str = np.array([np.array([ord(c) - ord('a') + 1 for c in input_str])])
        src = torch.tensor(input_str)
        tgt = torch.tensor([[0]])
        for _ in range(8):
            pred = model(src, tgt)
            pred = pred.argmax(dim=2)
            output += chr(pred[0, -1] + ord('a') - 1)
            tgt = torch.cat((tgt, pred[:, -1].unsqueeze(0)), dim=1)
        return output

# %%
# Hyperparameters
n_tokens = 27
d_model = 128
n_heads = 8
n_encoder_layers = 2
n_decoder_layers = 2
dropout = 0.2
batch_size = 10
epochs = 300
lr = 0.001

# model
model = TransformerModel(n_tokens, d_model, n_heads, n_encoder_layers, n_decoder_layers, dropout)

# loss function
criterion = nn.CrossEntropyLoss()

# optimizer-adam
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
def train(model, X, Y, criterion, optimizer, epochs, batch_size):
    model.train()
    losses = []
    for epoch in range(epochs):
        total_loss = 0
        for i in range(0, len(X), batch_size):
            x = X[i:i+batch_size]
            y = Y[i:i+batch_size]
            optimizer.zero_grad()
            output = model(x, y[:, :-1])
            y_expected = np.array([np.eye(27)[t] for t in y[:, 1:]])
            y_expected = torch.tensor(y_expected, dtype=torch.float)
            output1 = output.permute(0, 2, 1) 
            y_expected1 = y_expected.permute(0, 2, 1)
            # print(output1.shape, y_expected1.shape)
            loss = criterion(output1, y_expected1)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        # loss over all batches
        n_batches = len(X) // batch_size
        losses.append(total_loss / n_batches)
        print(f'Epoch: {epoch+1}/{epochs} Loss: {total_loss / n_batches}')
    # plot loss per epoch
    plt.plot(losses)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show() 
    return losses, model

losses, model = train(model, X, Y, criterion, optimizer, epochs, batch_size)
# save model
# torch.save(model.state_dict(), 'model.pth')
# Out:
# Epoch: 1/300 Loss: 1.9614891741956983
# Epoch: 2/300 Loss: 1.9641381398269109
# Epoch: 3/300 Loss: 1.9567024307591574
# Epoch: 4/300 Loss: 1.957624133314405
# Epoch: 5/300 Loss: 1.9571417348725455
# Epoch: 6/300 Loss: 1.9580325203282491
# Epoch: 7/300 Loss: 1.9567292162350245
# Epoch: 8/300 Loss: 1.9594153261184692
# Epoch: 9/300 Loss: 1.9480813368729182
# Epoch: 10/300 Loss: 1.9578615180083683
# Epoch: 11/300 Loss: 1.9502811910424913
# Epoch: 12/300 Loss: 1.9502758511475153
# Epoch: 13/300 Loss: 1.9455712815693447
# Epoch: 14/300 Loss: 1.9374895613534109
# Epoch: 15/300 Loss: 1.9370778019087656
# Epoch: 16/300 Loss: 1.951303196293967
# Epoch: 17/300 Loss: 1.944968852996826
# Epoch: 18/300 Loss: 1.934271845306669
# Epoch: 19/300 Loss: 1.9374632377283914
# Epoch: 20/300 Loss: 1.9331065048490252
# Epoch: 21/300 Loss: 1.941590222631182
# Epoch: 22/300 Loss: 1.9356689584255218
# Epoch: 23/300 Loss: 1.9336652980531965
# Epoch: 24/300 Loss: 1.931119247164045
# Epoch: 25/300 Loss: 1.9251737335750034
# Epoch: 26/300 Loss: 1.9205694251401084
# Epoch: 27/300 Loss: 1.9222008691515242
# Epoch: 28/300 Loss: 1.9250847193173
# Epoch: 29/300 Loss: 1.9231552456106458
# Epoch: 30/300 Loss: 1.9163493233067648
# Epoch: 31/300 Loss: 1.9153407011713302
# Epoch: 32/300 Loss: 1.9270728295189994
# Epoch: 33/300 Loss: 1.911154316493443
# Epoch: 34/300 Loss: 1.9201487236363548
# Epoch: 35/300 Loss: 1.9174609734330859
# Epoch: 36/300 Loss: 1.9129336825438907
# Epoch: 37/300 Loss: 1.9117114113058362
# Epoch: 38/300 Loss: 1.90637548327446
# Epoch: 39/300 Loss: 1.9142627544062478
# Epoch: 40/300 Loss: 1.908116340977805
# Epoch: 41/300 Loss: 1.906673013993672
# Epoch: 42/300 Loss: 1.906445197377886
# Epoch: 43/300 Loss: 1.9049603848797934
# Epoch: 44/300 Loss: 1.902169974361147
# Epoch: 45/300 Loss: 1.9037753198828016
# Epoch: 46/300 Loss: 1.894283286673682
# Epoch: 47/300 Loss: 1.8992398697989328
# Epoch: 48/300 Loss: 1.8995951703616551
# Epoch: 49/300 Loss: 1.9019633718899318
# Epoch: 50/300 Loss: 1.9020075784410748
# Epoch: 51/300 Loss: 1.8943763147081647
# Epoch: 52/300 Loss: 1.9023320387090956
# Epoch: 53/300 Loss: 1.8997804703031267
# Epoch: 54/300 Loss: 1.89153717313494
# Epoch: 55/300 Loss: 1.8953940795149122
# Epoch: 56/300 Loss: 1.8893382070745741
# Epoch: 57/300 Loss: 1.8835118286950248
# Epoch: 58/300 Loss: 1.8916107623917715
# Epoch: 59/300 Loss: 1.885982767854418
# Epoch: 60/300 Loss: 1.8887742720331464
# Epoch: 61/300 Loss: 1.8772531025750296
# Epoch: 62/300 Loss: 1.880935755627496
# Epoch: 63/300 Loss: 1.8761293232440948
# Epoch: 64/300 Loss: 1.8771567601816994
# Epoch: 65/300 Loss: 1.8759192151682718
# Epoch: 66/300 Loss: 1.8735321245874677
# Epoch: 67/300 Loss: 1.880860423530851
# Epoch: 68/300 Loss: 1.8758036289896285
# Epoch: 69/300 Loss: 1.8739718772683824
# Epoch: 70/300 Loss: 1.8748669867856163
# Epoch: 71/300 Loss: 1.8718225233895438
# Epoch: 72/300 Loss: 1.8746107971668244
# Epoch: 73/300 Loss: 1.8719261518546513
# Epoch: 74/300 Loss: 1.866144290992192
# Epoch: 75/300 Loss: 1.8712237361499242
# Epoch: 76/300 Loss: 1.865540382691792
# Epoch: 77/300 Loss: 1.8676062084947314
# Epoch: 78/300 Loss: 1.8613459757396154
# Epoch: 79/300 Loss: 1.8680674922466278
# Epoch: 80/300 Loss: 1.8630222363131388
# Epoch: 81/300 Loss: 1.858276115826198
# Epoch: 82/300 Loss: 1.8637434818063463
# Epoch: 83/300 Loss: 1.8594072825568062
# Epoch: 84/300 Loss: 1.8609708389214108
# Epoch: 85/300 Loss: 1.8615555664471217
# Epoch: 86/300 Loss: 1.8552430517332894
# Epoch: 87/300 Loss: 1.858455047607422
# Epoch: 88/300 Loss: 1.8565125095844268
# Epoch: 89/300 Loss: 1.854846351487296
# Epoch: 90/300 Loss: 1.8549712474005562
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 6 line 3
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a>     plt.show()
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a>     return losses, model
# ---> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a> losses, model = train(model, X, Y, criterion, optimizer, epochs, batch_size)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a> # save model
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a> # torch.save(model.state_dict(), 'model.pth')
#
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     loss = criterion(output1, y_expected1)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a>     loss.backward()
# ---> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a>     optimizer.step()
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a>     total_loss += loss.item()
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> # loss over all batches
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/adam.py:154, in Adam.step(self, closure)
#     151     state_steps = []
#     152     beta1, beta2 = group['betas']
# --> 154     self._init_group(
#     155         group,
#     156         params_with_grad,
#     157         grads,
#     158         exp_avgs,
#     159         exp_avg_sqs,
#     160         max_exp_avg_sqs,
#     161         state_steps)
#     163     adam(
#     164         params_with_grad,
#     165         grads,
#    (...)
#     182         found_inf=getattr(self, "found_inf", None),
#     183     )
#     185 return loss
#
# File ~/.local/lib/python3.10/site-packages/torch/optim/adam.py:93, in Adam._init_group(self, group, params_with_grad, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps)
#      91 if p.grad is not None:
#      92     params_with_grad.append(p)
# ---> 93     if p.grad.is_sparse:
#      94         raise RuntimeError('Adam does not support sparse gradients, please consider SparseAdam instead')
#      95     grads.append(p.grad)
#
# KeyboardInterrupt:

# %%
# loading the saved model
# model = TransformerModel(n_tokens, d_model, n_heads, n_encoder_layers, n_decoder_layers, dropout)
# model.load_state_dict(torch.load('model.pth'))
# model.eval()

# %%
def predict(model,input_str):
    model.eval()
    output = ''
    input_str = np.array([np.array([ord(c) - ord('a') + 1 for c in input_str])])
    src = torch.tensor(input_str)
    tgt = torch.tensor([[0]])
    for _ in range(8):
        pred = model(src, tgt)
        pred = pred.argmax(dim=2)
        output += chr(pred[0, -1] + ord('a') - 1)
        tgt = torch.cat((tgt, pred[:, -1].unsqueeze(0)), dim=1)
    return output

# %%
print(predict(model, 'dcmdllti'))
# Out:
# ppbbbbbb

# %%
# Function to check how many characters match in the two strings
def check(pred: str, true: str):
    correct = 0
    for a, b in zip(pred, true):
        if a == b:
            correct += 1
    return correct

# Function to score the model's performance
def evaluate(model):
    print("Obtaining metrics for eval data:")
    eval_data = pd.read_csv("eval_data.csv").to_numpy()
    results = {
        "pred": [],
        "true": [],
        "score": [],
    }
    correct = [0 for _ in range(9)]
    for x, y in eval_data:
        pred = predict(model, x)
        print(f"Predicted: {pred}, True: {y}")
        score = check(pred, y)
        results["pred"].append(pred)
        results["true"].append(y)
        results["score"].append(score)

        correct[score] += 1
    print("Eval dataset results:")
    for num_chr in range(9):
        print(
            f"Number of predictions with {num_chr} correct predictions: {correct[num_chr]}"
        )
    points = sum(correct[4:6]) * 0.5 + sum(correct[6:])
    marks = round(min(2, points / 1400 * 2) * 2) / 2  # Rounds to the nearest 0.5
    print(f"Points: {points}")
    print(f"Marks: {marks}")
    # Save predicitons and true sentences to inspect manually if required.
    pd.DataFrame.from_dict(results).to_csv("results_eval.csv", index=False)


evaluate(model)
# Out:
# Obtaining metrics for eval data:
# Predicted: yanizsda, True: ldlhgjuj
# Predicted: yanizsda, True: mffolhhl
# Predicted: psminhli, True: xjwbqnnq
# Predicted: yanizmgh, True: nqxwxmtb
# Predicted: psminhli, True: dlbdbgvx
# Predicted: psminhli, True: fwkibsou
# Predicted: yanizmgh, True: ulafntih
# Predicted: yanizsda, True: ontitdlb
# Predicted: psminhli, True: epprjfot
# Predicted: yanizmgh, True: sdgztwup
# Predicted: psminhli, True: sqcdadyx
# Predicted: psminhli, True: ojsllopa
# Predicted: yanizmgh, True: zdtsndhk
# Predicted: psminhli, True: kiwtuwyj
# Predicted: psminhli, True: jxfwiaky
# Predicted: yanizmgh, True: cxqzjrox
# Predicted: yanizsda, True: vyakrkdv
# Predicted: psminhli, True: rfoaeevr
# Predicted: yqzanopr, True: bgbcvwei
# Predicted: yanizsda, True: yrozhdru
# Predicted: yqzanopr, True: gnulhwmv
# Predicted: yanizsdz, True: kflttcgt
# Predicted: yanizsda, True: tlcmfsqf
# Predicted: yanizsda, True: kwnizswj
# Predicted: psminhli, True: ebyojfqs
# Predicted: psminhli, True: eyfqqwxb
# Predicted: psminhli, True: prgzmfap
# Predicted: yanizsda, True: urmvnzmp
# Predicted: yanizsda, True: itpsafkp
# Predicted: psminhli, True: gpksonaz
# Predicted: yqzanopr, True: xyhzjnnc
# Predicted: psminhli, True: toqhxqfm
# Predicted: yanizmgh, True: qepqztyt
# Predicted: psminhli, True: yjnifefh
# Predicted: yanizsda, True: usjbjkge
# Predicted: yanizmgh, True: njdgirlv
# Predicted: psminhli, True: roapftdm
# Predicted: psminhli, True: mbceqtud
# Predicted: yanizsda, True: xewtalxz
# Predicted: yanizmgh, True: pifykzti
# Predicted: yanizmgh, True: pjnobapi
# Predicted: psminhli, True: xyabkdzb
# Predicted: yanizsda, True: bzksupiw
# Predicted: psminhli, True: bfsjlqks
# Predicted: psminhli, True: fthjqsqz
# Predicted: yanizsda, True: mkelgcfa
# Predicted: yanizsda, True: xgljdrqh
# Predicted: yanizmgh, True: ulqiamgx
# Predicted: psminhli, True: tbotnnnx
# Predicted: psminhli, True: ayxthnwg
# Predicted: yanizsda, True: ocutpuma
# Predicted: yqzanopr, True: ruiunvnv
# Predicted: psminhli, True: nvmyhofq
# Predicted: yanizsda, True: dmihohme
# Predicted: psminhli, True: jnnhbhwu
# Predicted: psminhli, True: jgnkvigc
# Predicted: psminhli, True: vthmsydf
# Predicted: psminhli, True: agoighyc
# Predicted: yanizsda, True: urodyanz
# Predicted: psminhli, True: ewjnedwf
# Predicted: yanizsda, True: ufkhapao
# Predicted: psminhli, True: pohxluuh
# Predicted: psminhli, True: mzfmihwb
# Predicted: yanizsda, True: grtqxpkg
# Predicted: psminhli, True: ihqzfuyh
# Predicted: yanizmgh, True: mtrijxpx
# Predicted: yanizmgh, True: jacunzrt
# Predicted: psminhli, True: jmsibxzx
# Predicted: yanizmgh, True: zxmouros
# Predicted: psminhli, True: qcylwjij
# Predicted: psminhli, True: jcjguuml
# Predicted: yanizsda, True: htoylrdy
# Predicted: yanizsdz, True: hdbsyxgo
# Predicted: psminhli, True: twhrzhpo
# Predicted: psminhli, True: tzozbzkq
# Predicted: psminhli, True: xektrpxg
# Predicted: yanizsda, True: uylvafqt
# Predicted: yqzanopr, True: ielmvefm
# Predicted: psminhli, True: eshozycp
# Predicted: psminhli, True: rwsrjndq
# Predicted: yanizsda, True: bqfvtvxy
# Predicted: yanizmgh, True: pdjbtfke
# Predicted: psminhli, True: fcecxdvp
# Predicted: psminhli, True: zdykapht
# Predicted: yanizsda, True: bvziihmm
# Predicted: psminhli, True: ytdykoen
# Predicted: yanizmgh, True: athycupc
# Predicted: psminhli, True: iptnopxl
# Predicted: psminhli, True: jptifnpk
# Predicted: psminhli, True: vdhsxrwj
# Predicted: psminhli, True: seefipbg
# Predicted: yanizsda, True: vjlwvipa
# Predicted: psminhli, True: cjukedpm
# Predicted: psminhli, True: ibkkidaj
# Predicted: psminhli, True: jgmslnfn
# Predicted: yqzanopr, True: hjsfgtef
# Predicted: yanizsda, True: tndaarzp
# Predicted: psminhli, True: jsooxfnj
# Predicted: yanizmgh, True: regsxhwc
# Predicted: yqzanopr, True: chbwfbec
# Predicted: psminhli, True: ivlrotew
# Predicted: psminhli, True: zmjofhrn
# Predicted: yanizsda, True: ahhbkcph
# Predicted: psminhli, True: kmgsiuey
# Predicted: yanizmgh, True: zoyzpdal
# Predicted: psminhli, True: fvejjgmq
# Predicted: psminhli, True: lzarfold
# Predicted: psminhli, True: dfyppwom
# Predicted: psminhli, True: lqfnfude
# Predicted: psminhli, True: sohvxbag
# Predicted: yanizsda, True: cmpldiln
# Predicted: yanizsda, True: bczttemb
# Predicted: yanizmgh, True: hxtrzjmk
# Predicted: psminhli, True: srnldykf
# Predicted: yanizsda, True: exjxkykw
# Predicted: psminhli, True: negfdyxu
# Predicted: psminhli, True: ojlooxle
# Predicted: psminhli, True: aydfgvcj
# Predicted: psminhli, True: gctmyezn
# Predicted: yanizmgh, True: ffbbwble
# Predicted: psminhli, True: qtvtmkbh
# Predicted: psminhli, True: vgnkumyd
# Predicted: yanizmgh, True: vplwtikn
# Predicted: psminhli, True: banzppfc
# Predicted: psminhli, True: mfviehch
# Predicted: yanizsda, True: gitizcxg
# Predicted: psminhli, True: ddywdmal
# Predicted: psminhli, True: xggnwnus
# Predicted: psminhli, True: qcroadog
# Predicted: yanizsda, True: llxpluuk
# Predicted: psminhli, True: oqonzwpz
# Predicted: psminhli, True: pmecrdoe
# Predicted: psminhli, True: jgxjqgmg
# Predicted: psminhli, True: jojlvweb
# Predicted: yqzanopr, True: penwupbo
# Predicted: yanizsda, True: iymlgbkl
# Predicted: psminhli, True: cnfsqbfk
# Predicted: yanizmgh, True: bwfxajdv
# Predicted: psminhli, True: aoxbcnhw
# Predicted: yanizmgh, True: mjepyffl
# Predicted: psminhli, True: pembeknx
# Predicted: psminhli, True: mehxshat
# Predicted: psminhli, True: zuqctwsm
# Predicted: psminhli, True: pmbnxsub
# Predicted: psminhli, True: vgmphiaz
# Predicted: psminhli, True: mlsxgxzf
# Predicted: yqzanopr, True: toovedaw
# Predicted: psminhli, True: ikececqc
# Predicted: yanizsda, True: zrsbrlfv
# Predicted: psminhli, True: oyayqhoy
# Predicted: psminhli, True: sstpmimx
# Predicted: psminhli, True: xiegnnzr
# Predicted: yqzanopr, True: ynyhgmhh
# Predicted: yanizsdz, True: roppiugi
# Predicted: psminhli, True: bqnooszc
# Predicted: psminhli, True: qikonpop
# Predicted: psminhli, True: oucblwms
# Predicted: psminhli, True: pvldrmgo
# Predicted: psminhli, True: qhhpwvlh
# Predicted: psminhli, True: jlnnlmbb
# Predicted: yanizsda, True: pfarkofu
# Predicted: yanizmgh, True: udgahosk
# Predicted: yanizsda, True: vjfbzgpz
# Predicted: yanizsda, True: wkgajrdg
# Predicted: psminhli, True: ocbvmkmf
# Predicted: yanizsda, True: cuclqvcp
# Predicted: psminhli, True: nyiyuupm
# Predicted: psminhli, True: glimsaal
# Predicted: psminhli, True: knmewove
# Predicted: yanizsda, True: txvwptte
# Predicted: yqzanopr, True: tqirvati
# Predicted: yqzanopr, True: wmjwcpzh
# Predicted: psminhli, True: kwrpoqcj
# Predicted: psminhli, True: tfosqgpn
# Predicted: psminhli, True: kqptzoll
# Predicted: yanizsda, True: nxduzfje
# Predicted: psminhli, True: nnqpbdvp
# Predicted: psminhli, True: ewwxabar
# Predicted: psminhli, True: clerycsk
# Predicted: psminhli, True: ekbvolny
# Predicted: yqzanopr, True: uhoodxhl
# Predicted: yanizsda, True: powpfyfw
# Predicted: yqzanopr, True: qylqsyee
# Predicted: psminhli, True: otbctryg
# Predicted: psminhli, True: zsagnplj
# Predicted: psminhli, True: zthxjsxj
# Predicted: yanizmgh, True: pkrkdsnx
# Predicted: yanizsda, True: oqpoqklp
# Predicted: yanizmgh, True: ufkksiit
# Predicted: psminhli, True: ddnlikhm
# Predicted: psminhli, True: dvannxea
# Predicted: psminhli, True: qcmrtxdp
# Predicted: yanizsda, True: oemfzuqk
# Predicted: yanizsda, True: uazeqhaa
# Predicted: psminhli, True: pkylrqob
# Predicted: psminhli, True: yyprjsvb
# Predicted: yanizsda, True: mdusrccu
# Predicted: yqzanopr, True: hojdgcem
# Predicted: yanizsdz, True: oqjewdig
# Predicted: psminhli, True: ftpmcaos
# Predicted: yqzanopr, True: ihwxjbat
# Predicted: psminhli, True: whboabsx
# Predicted: psminhli, True: tclqchgh
# Predicted: yqzanopr, True: fnkyjnbu
# Predicted: psminhli, True: vtiyalrh
# Predicted: psminhli, True: zqfnwxuw
# Predicted: yanizsda, True: bimyiumt
# Predicted: yanizsda, True: hciienev
# Predicted: psminhli, True: locleucw
# Predicted: yanizsda, True: zujbenlx
# Predicted: psminhli, True: npzkwomm
# Predicted: psminhli, True: ghlekttq
# Predicted: psminhli, True: fnnsicsw
# Predicted: yanizsda, True: wnyyzugs
# Predicted: psminhli, True: oizbmuns
# Predicted: psminhli, True: mlwgtyoa
# Predicted: psminhli, True: fmioctjk
# Predicted: yanizmgh, True: iysfxcfv
# Predicted: yqzanopr, True: itpwcfkx
# Predicted: yanizsda, True: zoneushi
# Predicted: psminhli, True: tcavccrl
# Predicted: yqzanopr, True: bpweppyz
# Predicted: psminhli, True: eelrdxvj
# Predicted: yanizmgh, True: bwzirhok
# Predicted: yqzanopr, True: xokmkjjo
# Predicted: yanizsda, True: hhlpfvim
# Predicted: psminhli, True: xirnydrr
# Predicted: psminhli, True: ojwhdghy
# Predicted: psminhli, True: kronoxxz
# Predicted: yanizmgh, True: wpuxzacb
# Predicted: yanizsda, True: hztdwmsl
# Predicted: yanizsda, True: pidaarqb
# Predicted: psminhli, True: xxcuiqgq
# Predicted: yanizmgh, True: cfhxcbgo
# Predicted: psminhli, True: ncyfjajs
# Predicted: yanizsda, True: xfwehawf
# Predicted: yanizsda, True: hkfdnnup
# Predicted: psminhli, True: miovptrp
# Predicted: psminhli, True: djgwzdlq
# Predicted: psminhli, True: nintiujr
# Predicted: psminhli, True: afvmhdos
# Predicted: yanizsda, True: czqmvxgw
# Predicted: yqzanopr, True: gqztpnrh
# Predicted: yanizsda, True: kftrlqxy
# Predicted: psminhli, True: kxddnfvw
# Predicted: psminhli, True: fhasqdsu
# Predicted: psminhli, True: meszqwhk
# Predicted: yqzanopr, True: guhnxejt
# Predicted: yqzanopr, True: cjqxleal
# Predicted: psminhli, True: jtybicpw
# Predicted: yanizsda, True: lrrizqpw
# Predicted: psminhli, True: qqohzuem
# Predicted: psminhli, True: rgznvmob
# Predicted: psminhli, True: duepdvmz
# Predicted: yqzanopr, True: jliucxjl
# Predicted: psminhli, True: xoxfhkcd
# Predicted: psminhli, True: dynmrsyc
# Predicted: psminhli, True: vppiqaye
# Predicted: yanizsda, True: bofglosi
# Predicted: psminhli, True: fbqzyqcx
# Predicted: yanizmgh, True: rbgdoomp
# Predicted: yqzanopr, True: dyqctpqe
# Predicted: psminhli, True: ziwjcqxr
# Predicted: yanizmgh, True: oeaeysnb
# Predicted: psminhli, True: wsbqobgk
# Predicted: psminhli, True: lfqbubsj
# Predicted: yanizsda, True: aaumcuua
# Predicted: psminhli, True: yyihzpkk
# Predicted: yanizsdz, True: hqtntcfw
# Predicted: psminhli, True: keokvwwn
# Predicted: yanizmgh, True: btkzrkbd
# Predicted: yanizsda, True: eaapuvgb
# Predicted: psminhli, True: zdvwwhgy
# Predicted: psminhli, True: lvgdugaz
# Predicted: yanizsda, True: hqlgnzoo
# Predicted: psminhli, True: fhckisbt
# Predicted: yanizsda, True: gxxqpjht
# Predicted: psminhli, True: whppeqnb
# Predicted: yanizsda, True: rupbzmha
# Predicted: psminhli, True: wfqzsdxf
# Predicted: psminhli, True: jbbaxrta
# Predicted: psminhli, True: vfnugfsu
# Predicted: psminhli, True: gtrtjlux
# Predicted: yanizmgh, True: eajwgsjr
# Predicted: psminhli, True: obualrxp
# Predicted: psminhli, True: fcmoqvwr
# Predicted: psminhli, True: jcjtgvdl
# Predicted: psminhli, True: pfxjwfvs
# Predicted: psminhli, True: jbgvhkcy
# Predicted: yanizsda, True: zovegtup
# Predicted: yanizsda, True: swhbnhek
# Predicted: psminhli, True: zdpkxrzy
# Predicted: psminhli, True: gillbyce
# Predicted: psminhli, True: nrxxghyr
# Predicted: yanizmgh, True: aapvviya
# Predicted: psminhli, True: ryffugok
# Predicted: yqzanopr, True: uqvziion
# Predicted: yanizmgh, True: wdijxeji
# Predicted: psminhli, True: mwuxtxtf
# Predicted: psminhli, True: qjeiooat
# Predicted: yanizsda, True: hxmlpkyc
# Predicted: psminhli, True: oswkvyrm
# Predicted: yanizmgh, True: vjxflwxd
# Predicted: psminhli, True: lmtdtnfy
# Predicted: yanizsda, True: lcgueqwr
# Predicted: yqzanopr, True: uvxzsuaa
# Predicted: psminhli, True: kodqpkeb
# Predicted: psminhli, True: bsisegsz
# Predicted: yanizsda, True: ehnkougx
# Predicted: psminhli, True: rvcqgcdx
# Predicted: psminhli, True: wwkruduh
# Predicted: psminhli, True: delawgid
# Predicted: yqzanopr, True: winesfbz
# Predicted: psminhli, True: ilnhynpr
# Predicted: yqzanopr, True: lrclfapt
# Predicted: yqzanopr, True: ugjaossu
# Predicted: psminhli, True: lrrdezmp
# Predicted: yqzanopr, True: ishsxdox
# Predicted: yanizmgh, True: isqrzjoq
# Predicted: psminhli, True: rookfihj
# Predicted: yqzanopr, True: oalfhkpf
# Predicted: yanizsda, True: pdhesvgw
# Predicted: yanizmgh, True: awjaxvwv
# Predicted: psminhli, True: mztkgnhk
# Predicted: yanizsda, True: upqcevkl
# Predicted: yanizmgh, True: nypwmkyt
# Predicted: yanizsda, True: mitcuanv
# Predicted: yanizsda, True: tgkvxnup
# Predicted: psminhli, True: ffklhdmc
# Predicted: psminhli, True: yzveorgx
# Predicted: yanizmgh, True: avtzmgsa
# Predicted: yqzanopr, True: akfzordc
# Predicted: yanizsda, True: nnotaalo
# Predicted: psminhli, True: epvjgtbf
# Predicted: psminhli, True: mipfqcbq
# Predicted: psminhli, True: qcrdtdam
# Predicted: psminhli, True: zgpfcroc
# Predicted: yanizsda, True: muvduznm
# Predicted: psminhli, True: vglfgpae
# Predicted: psminhli, True: qwudfgfd
# Predicted: psminhli, True: jykxasga
# Predicted: psminhli, True: dkfwbjvj
# Predicted: psminhli, True: lfurqqyb
# Predicted: psminhli, True: tpcsxapg
# Predicted: psminhli, True: psijklyu
# Predicted: yanizsda, True: kvrcuwdo
# Predicted: yanizsda, True: ozailciw
# Predicted: psminhli, True: tzgsaerf
# Predicted: psminhli, True: wormvnzo
# Predicted: psminhli, True: jtagktcq
# Predicted: yanizsda, True: cduuxold
# Predicted: psminhli, True: qzlnkkkw
# Predicted: psminhli, True: coxbjokk
# Predicted: yanizmgh, True: hhnnhpgs
# Predicted: psminhli, True: kmqcvfvg
# Predicted: yanizsda, True: qsrrriwy
# Predicted: psminhli, True: piopkilz
# Predicted: yqzanopr, True: qhoimdyp
# Predicted: psminhli, True: woyyehnj
# Predicted: yqzanopr, True: zeekayeh
# Predicted: yanizsda, True: uljzuwoi
# Predicted: psminhli, True: qdphpxdy
# Predicted: psminhli, True: spqravug
# Predicted: yqzanopr, True: pnupfsxv
# Predicted: yqzanopr, True: xjinttfp
# Predicted: psminhli, True: mryhfldm
# Predicted: yanizsda, True: kkfglexe
# Predicted: psminhli, True: qjfrfxrw
# Predicted: yanizsdz, True: yxblphob
# Predicted: psminhli, True: saojqyfk
# Predicted: psminhli, True: zixdkves
# Predicted: psminhli, True: wyosxahm
# Predicted: yanizsda, True: pgcheddh
# Predicted: yanizsdz, True: ztuappna
# Predicted: yanizsda, True: nqremrxw
# Predicted: yanizsda, True: igdcfdry
# Predicted: yqzanopr, True: pqpjfqgp
# Predicted: psminhli, True: owtmtkuj
# Predicted: psminhli, True: oxdnfrsz
# Predicted: yanizsda, True: qnozzplk
# Predicted: psminhli, True: dtulxtio
# Predicted: psminhli, True: poylfbpk
# Predicted: yanizsda, True: mmgqazew
# Predicted: psminhli, True: jogephld
# Predicted: yqzanopr, True: nlnbgiba
# Predicted: yanizsda, True: vbgxsfre
# Predicted: psminhli, True: bevsebcx
# Predicted: psminhli, True: ahgoazux
# Predicted: yanizsda, True: twfqjzpd
# Predicted: psminhli, True: nfslhmft
# Predicted: psminhli, True: zpmobmul
# Predicted: yanizsda, True: oraclvyk
# Predicted: psminhli, True: jilwfzsw
# Predicted: yanizsda, True: qtqukouz
# Predicted: yanizmgh, True: wqibqgsx
# Predicted: yqzanopr, True: unziszor
# Predicted: yqzanopr, True: ooqpzzam
# Predicted: yanizmgh, True: agklbwsq
# Predicted: psminhli, True: zowuiwuh
# Predicted: yqzanopr, True: tgvrwluk
# Predicted: psminhli, True: wcnyfbpw
# Predicted: yanizsda, True: eiirqign
# Predicted: psminhli, True: xoebawgw
# Predicted: psminhli, True: mtadlkty
# Predicted: psminhli, True: dgzuzerp
# Predicted: yanizsda, True: ufgoalsp
# Predicted: yanizsda, True: drlslinm
# Predicted: yqzanopr, True: rhgvrmwu
# Predicted: yanizmgh, True: xvvxoxzg
# Predicted: yanizmgh, True: jflbexud
# Predicted: psminhli, True: qmbnnhrf
# Predicted: yanizsda, True: hvlsrwrc
# Predicted: psminhli, True: nytpdsql
# Predicted: psminhli, True: razhfxof
# Predicted: psminhli, True: lpwmtszo
# Predicted: yqzanopr, True: utaqmyxs
# Predicted: psminhli, True: zuwkpjlh
# Predicted: psminhli, True: mgdcxqah
# Predicted: yanizsda, True: ltktqlzu
# Predicted: psminhli, True: wseqenpb
# Predicted: psminhli, True: icbaestd
# Predicted: psminhli, True: tbjbwnru
# Predicted: yanizmgh, True: hyuyzwiw
# Predicted: psminhli, True: veiqogkd
# Predicted: psminhli, True: dqolphel
# Predicted: psminhli, True: olanzjex
# Predicted: psminhli, True: xpdmmhvj
# Predicted: psminhli, True: yvvtndox
# Predicted: psminhli, True: jdsdhwjr
# Predicted: psminhli, True: ezptzguz
# Predicted: psminhli, True: vevksars
# Predicted: psminhli, True: xntiqqok
# Predicted: yanizsda, True: lkpcxnfx
# Predicted: yqzanopr, True: nmhlvflm
# Predicted: psminhli, True: wykulkfs
# Predicted: yanizsda, True: rffgklqc
# Predicted: yanizsdz, True: gdmdmiqc
# Predicted: psminhli, True: mlwhofac
# Predicted: yanizmgh, True: gymzbbxr
# Predicted: psminhli, True: nclrqmbb
# Predicted: psminhli, True: ydgskyez
# Predicted: psminhli, True: lcwfjlur
# Predicted: psminhli, True: ezftqbsu
# Predicted: psminhli, True: bnmpypor
# Predicted: yanizsda, True: hbpjjxqe
# Predicted: psminhli, True: zplqbdlq
# Predicted: psminhli, True: ayvyiqiq
# Predicted: psminhli, True: azdszazr
# Predicted: psminhli, True: iehtsgxa
# Predicted: yanizmgh, True: hlcugqxr
# Predicted: psminhli, True: oxzirdcs
# Predicted: yanizsda, True: ohiljqgx
# Predicted: yqzanopr, True: tousprfv
# Predicted: yqzanopr, True: rwqetnnf
# Predicted: yanizmgh, True: krflztgt
# Predicted: yanizsda, True: cxqugeal
# Predicted: psminhli, True: zuvyemqh
# Predicted: psminhli, True: isqvptqo
# Predicted: yqzanopr, True: sgtvswgb
# Predicted: psminhli, True: gqwsawug
# Predicted: psminhli, True: etavmupd
# Predicted: yanizsda, True: uyznsmmf
# Predicted: yanizsda, True: uillhjws
# Predicted: yanizsdz, True: amhexxud
# Predicted: psminhli, True: qqjssjmg
# Predicted: yanizsda, True: zryhzcnv
# Predicted: psminhli, True: tzkvnlzz
# Predicted: yanizsda, True: znkiihoi
# Predicted: psminhli, True: biwnavdx
# Predicted: psminhli, True: whqlrrfe
# Predicted: psminhli, True: jgytctlj
# Predicted: psminhli, True: rgbvdrun
# Predicted: psminhli, True: dgzootyr
# Predicted: psminhli, True: mqllykkp
# Predicted: yanizsda, True: kwbazhiv
# Predicted: yanizsda, True: xbwibyru
# Predicted: yanizmgh, True: kelbxklh
# Predicted: psminhli, True: ejxmedmr
# Predicted: psminhli, True: pawcildy
# Predicted: psminhli, True: xrgjttwg
# Predicted: yanizmgh, True: gexthiqa
# Predicted: yqzanopr, True: jfidjquw
# Predicted: yqzanopr, True: fzpjscjo
# Predicted: psminhli, True: muznpajx
# Predicted: psminhli, True: xgdwkhkl
# Predicted: psminhli, True: znwsyitd
# Predicted: yanizsda, True: wfmxecys
# Predicted: psminhli, True: edocmcta
# Predicted: yqzanopr, True: sjrdqgsi
# Predicted: psminhli, True: fjskgjuo
# Predicted: psminhli, True: tmlmphea
# Predicted: yanizsda, True: tzdobylk
# Predicted: yqzanopr, True: pkqmspne
# Predicted: psminhli, True: zazvpsjm
# Predicted: psminhli, True: oecwnyhk
# Predicted: yanizsda, True: hnlmjqnw
# Predicted: yanizsda, True: wtnvrwxu
# Predicted: psminhli, True: zvbtdksk
# Predicted: yqzanopr, True: uyfueliy
# Predicted: yanizsda, True: pbftzzso
# Predicted: psminhli, True: rvajbemy
# Predicted: psminhli, True: wlgkhyem
# Predicted: psminhli, True: gflhhwmb
# Predicted: yanizmgh, True: emgrxuqk
# Predicted: psminhli, True: neqoopxw
# Predicted: psminhli, True: kfvgawwr
# Predicted: psminhli, True: npvutumd
# Predicted: psminhli, True: prwmcies
# Predicted: yanizsda, True: rfgxkhod
# Predicted: psminhli, True: crohkkfz
# Predicted: yanizsda, True: uksbqjkt
# Predicted: psminhli, True: zfcamams
# Predicted: yanizsda, True: wzzdvhji
# Predicted: yqzanopr, True: kzrptjuv
# Predicted: psminhli, True: rrhlvjgg
# Predicted: yanizsda, True: usumdbut
# Predicted: psminhli, True: bgzwhgqy
# Predicted: yanizsda, True: jxpokmiw
# Predicted: psminhli, True: gmqctcxq
# Predicted: psminhli, True: clmisjwh
# Predicted: yanizmgh, True: yoridbmf
# Predicted: psminhli, True: vcgqtfvf
# Predicted: yanizmgh, True: smncctvr
# Predicted: yanizsda, True: gzzuvjae
# Predicted: psminhli, True: asjcswcu
# Predicted: yanizmgh, True: wmjjfoac
# Predicted: yanizsda, True: vmseamzo
# Predicted: psminhli, True: megmebco
# Predicted: psminhli, True: nnbmbbwx
# Predicted: yqzanopr, True: hhcgqxya
# Predicted: psminhli, True: iqqxmuol
# Predicted: psminhli, True: egygfuez
# Predicted: psminhli, True: wmhvldse
# Predicted: yqzanopr, True: mbgitxmi
# Predicted: psminhli, True: sbkimvef
# Predicted: yanizmgh, True: jlpkxhlq
# Predicted: yanizmgh, True: pmhkaqar
# Predicted: psminhli, True: bhoitbha
# Predicted: yqzanopr, True: hiljhhdu
# Predicted: yanizsda, True: hhijcmvy
# Predicted: psminhli, True: pngjfwfb
# Predicted: yanizsda, True: hwttwrlx
# Predicted: psminhli, True: jxjotror
# Predicted: psminhli, True: yqhwggdr
# Predicted: yanizsda, True: nghsykra
# Predicted: psminhli, True: ztwvnwiw
# Predicted: psminhli, True: rsmjwzuq
# Predicted: yanizmgh, True: irczlgxi
# Predicted: psminhli, True: cxojxhja
# Predicted: psminhli, True: tgirbala
# Predicted: psminhli, True: gsoppguw
# Predicted: psminhli, True: xpbcvvbm
# Predicted: yanizsda, True: bbnuoblz
# Predicted: yanizmgh, True: ciyxfyui
# Predicted: yanizmgh, True: rsfguwlw
# Predicted: psminhli, True: xrbnfdrx
# Predicted: yqzanopr, True: ndbokneu
# Predicted: yqzanopr, True: conuwqrd
# Predicted: psminhli, True: kmdmmejt
# Predicted: yqzanopr, True: kokwyifp
# Predicted: psminhli, True: bdjynine
# Predicted: yanizsdz, True: aszmdzsv
# Predicted: psminhli, True: bgymupox
# Predicted: psminhli, True: gepafgwf
# Predicted: psminhli, True: wvuaawjw
# Predicted: psminhli, True: mffmcfih
# Predicted: yqzanopr, True: ygxxnjdv
# Predicted: yqzanopr, True: gaqwifpv
# Predicted: psminhli, True: tkdjffjk
# Predicted: yanizsda, True: uqhlyfcd
# Predicted: yanizsda, True: uhdfgwas
# Predicted: psminhli, True: vovymkxu
# Predicted: psminhli, True: eoduyucu
# Predicted: yanizsda, True: glkzjwta
# Predicted: psminhli, True: lnpjhsrj
# Predicted: yanizsda, True: wbbtafhx
# Predicted: yqzanopr, True: bvwtzgia
# Predicted: yanizsdz, True: hoadoqam
# Predicted: psminhli, True: wxjqkgbm
# Predicted: psminhli, True: nnxwgauy
# Predicted: yanizsda, True: hmaqqaup
# Predicted: psminhli, True: swoypgrc
# Predicted: yanizmgh, True: zpkshobw
# Predicted: yanizsda, True: zlvwvsgp
# Predicted: yanizmgh, True: ofpvednx
# Predicted: psminhli, True: zcjzokqc
# Predicted: yanizsda, True: aeycggtv
# Predicted: psminhli, True: yfvezfxf
# Predicted: yanizsda, True: otnkaebo
# Predicted: psminhli, True: dqzjrrna
# Predicted: psminhli, True: veijborq
# Predicted: psminhli, True: wubtpqmw
# Predicted: psminhli, True: fmrzfdfu
# Predicted: psminhli, True: aaprdqbn
# Predicted: psminhli, True: vwgsjarh
# Predicted: yanizsda, True: cfznznja
# Predicted: yqzanopr, True: rdcdczbm
# Predicted: psminhli, True: dozuwyyn
# Predicted: psminhli, True: vbattnka
# Predicted: yanizsdz, True: stgowdzi
# Predicted: yanizsda, True: jvwskteo
# Predicted: psminhli, True: vkbvcwlz
# Predicted: psminhli, True: xltarqdk
# Predicted: yqzanopr, True: oqtyblru
# Predicted: psminhli, True: cdrahdzf
# Predicted: psminhli, True: bgicqhqh
# Predicted: yanizsda, True: npqtnmom
# Predicted: yanizsda, True: rbauxwfc
# Predicted: yanizsda, True: qoasllju
# Predicted: yanizsda, True: qqdxishu
# Predicted: psminhli, True: sevexpoj
# Predicted: psminhli, True: ghbwugrc
# Predicted: yqzanopr, True: wafeavui
# Predicted: yanizmgh, True: pqqwopfi
# Predicted: psminhli, True: ljzwvgkp
# Predicted: yanizsda, True: pqnmsner
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 10 line 4
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=36'>37</a>     # Save predicitons and true sentences to inspect manually if required.
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=37'>38</a>     pd.DataFrame.from_dict(results).to_csv("results_eval.csv", index=False)
# ---> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=40'>41</a> evaluate(model)
#
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a> correct = [0 for _ in range(9)]
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> for x, y in eval_data:
# ---> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a>     pred = predict(model, x)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=20'>21</a>     print(f"Predicted: {pred}, True: {y}")
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a>     score = check(pred, y)
#
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 10 line 8
#       <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> tgt = torch.tensor([[0]])
#       <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> for _ in range(8):
# ----> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>     pred = model(src, tgt)
#       <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a>     pred = pred.argmax(dim=2)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>     output += chr(pred[0, -1] + ord('a') - 1)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# /home/shravya/Desktop/Sem 5/DL/ass3/1.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> tgt = self.embedding(tgt) * math.sqrt(self.d_model)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> tgt = self.pos_encoder(tgt)
# ---> <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a> output = self.transformer(src, tgt)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> output = self.decoder(output)
#      <a href='vscode-notebook-cell:/home/shravya/Desktop/Sem%205/DL/ass3/1.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> return output
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:204, in Transformer.forward(self, src, tgt, src_mask, tgt_mask, memory_mask, src_key_padding_mask, tgt_key_padding_mask, memory_key_padding_mask, src_is_causal, tgt_is_causal, memory_is_causal)
#     201 if src.size(-1) != self.d_model or tgt.size(-1) != self.d_model:
#     202     raise RuntimeError("the feature number of src and tgt must be equal to d_model")
# --> 204 memory = self.encoder(src, mask=src_mask, src_key_padding_mask=src_key_padding_mask,
#     205                       is_causal=src_is_causal)
#     206 output = self.decoder(tgt, memory, tgt_mask=tgt_mask, memory_mask=memory_mask,
#     207                       tgt_key_padding_mask=tgt_key_padding_mask,
#     208                       memory_key_padding_mask=memory_key_padding_mask,
#     209                       tgt_is_causal=tgt_is_causal, memory_is_causal=memory_is_causal)
#     210 return output
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:387, in TransformerEncoder.forward(self, src, mask, src_key_padding_mask, is_causal)
#     384 is_causal = _detect_is_causal_mask(mask, is_causal, seq_len)
#     386 for mod in self.layers:
# --> 387     output = mod(output, src_mask=mask, is_causal=is_causal, src_key_padding_mask=src_key_padding_mask_for_layers)
#     389 if convert_to_nested:
#     390     output = output.to_padded_tensor(0., src.size())
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:669, in TransformerEncoderLayer.forward(self, src, src_mask, src_key_padding_mask, is_causal)
#     667 if torch.overrides.has_torch_function(tensor_args):
#     668     why_not_sparsity_fast_path = "some Tensor argument has_torch_function"
# --> 669 elif not all((x.device.type in _supported_device_type) for x in tensor_args):
#     670     why_not_sparsity_fast_path = ("some Tensor argument's device is neither one of "
#     671                                   f"{_supported_device_type}")
#     672 elif torch.is_grad_enabled() and any(x.requires_grad for x in tensor_args):
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:669, in <genexpr>(.0)
#     667 if torch.overrides.has_torch_function(tensor_args):
#     668     why_not_sparsity_fast_path = "some Tensor argument has_torch_function"
# --> 669 elif not all((x.device.type in _supported_device_type) for x in tensor_args):
#     670     why_not_sparsity_fast_path = ("some Tensor argument's device is neither one of "
#     671                                   f"{_supported_device_type}")
#     672 elif torch.is_grad_enabled() and any(x.requires_grad for x in tensor_args):
#
# KeyboardInterrupt:
